# %%
import os
import sys

PROJECT_ROOT = os.path.abspath("..")
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

print(PROJECT_ROOT)
# Out:
# d:\Property Intelligence Platform

# %%
import numpy as np
import pandas as pd

# %%
from src.data.ingestion import load_data

flats = load_data("../data/interim/flats_cleaned.csv")
houses = load_data("../data/interim/houses_cleaned.csv")
# Out:
# Dataset loaded successfully.
# Rows: 2997
# Columns: 20
# Dataset loaded successfully.
# Rows: 964
# Columns: 20

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                                    property_name property_type  \
# 0  4 Bedroom House for sale in Sector 92 Gurgaon         house
# 1                4 BHK Flat in Sector 92 Gurgaon          flat
# 2  4 Bedroom House for sale in Sector 33 Gurgaon         house
# 3               3 BHK Flat in Sector 67A Gurgaon          flat
# 4  6 Bedroom House for sale in Sector 46 Gurgaon         house
#
#                                    society  price  price_per_sqft    area  \
# 0  sare crescent parc royal greens phase 1   0.85          4877.0  1743.0
# 1                  sare green parc phase 3   1.08          5150.0  2097.0
# 2                 unitech uniworld resorts   8.00         11428.0  7000.0
# 3                       ireo the corridors   1.60          9264.0  1727.0
# 4                            rwa sector 46   4.50         24390.0  1845.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                 Built Up area: 1743 (161.93 sq.m.)        4         4
# 1             Super Built up area 2090(194.17 sq.m.)        4         4
# 2                       Plot area 7000(650.32 sq.m.)        4         4
# 3  Super Built up area 1727(160.44 sq.m.)Carpet a...        3         3
# 4  Plot area 204(170.57 sq.m.)Built Up area: 206 ...        6         6
#
#   balcony                                 additionalRoom  \
# 0       3                                  not available
# 1       2                                   servant room
# 2      3+  pooja room,servant room,study room,store room
# 3       2                                     store room
# 4      3+                                     store room
#
#                                              address  floorNum      facing  \
# 0  Sec -92 Gurgaon, Sector 92 Gurgaon, Gurgaon, H...       4.0         NaN
# 1                                                NaN      16.0         NaN
# 2                Sector 33 Gurgaon, Gurgaon, Haryana       2.0        West
# 3          000, Sector 67A Gurgaon, Gurgaon, Haryana       3.0       North
# 4  8 Marla Built Up As Bmt, Gf,ff, 6bhk Demand-4....       3.0  North-East
#
#       agePossession                                    nearbyLocations  \
# 0         undefined  ['Yadav Clinic', 'Bangali Clinic', 'Dr. J. S. ...
# 1   0 to 1 Year Old  ['Huda Metro Station', 'Sector Road', 'Delhi-J...
# 2      10+ Year Old  ['Rajiv Chowk Mosque', 'Icici bank ATM', 'Stan...
# 3   0 to 1 Year Old  ['Huda Metro Station (Gurugram)', 'Paras Trini...
# 4  5 to 10 Year Old  ['Axis bank ATM', 'State bank of india ATM', '...
#
#                                          description  \
# 0  4bhk penthouse for new property in sare cresce...
# 1  Only end user and buyers to contact. Flat in r...
# 2  Why buy in unitech the villas?\nJust minutes a...
# 3  Brokers please excuse\n3 bhk +store room resid...
# 4  Looking for a independent house in gurgaon's p...
#
#                                       furnishDetails  \
# 0  ['1 Light', 'No AC', 'No Bed', 'No Chimney', '...
# 1                                                NaN
# 2                                                NaN
# 3  ['3 Wardrobe', '1 Water Purifier', '4 Fan', '1...
# 4  ['5 Wardrobe', '1 Water Purifier', '13 Fan', '...
#
#                                             features  \
# 0                                                NaN
# 1  ['Security / Fire Alarm', 'Intercom Facility',...
# 2  ['Private Garden / Terrace', 'False Ceiling Li...
# 3  ['Water purifier', 'Security / Fire Alarm', 'P...
# 4  ['Private Garden / Terrace', 'High Ceiling Hei...
#
#                                               rating
# 0  ['Environment5 out of 5', 'Lifestyle4 out of 5...
# 1  ['Safety3 out of 5', 'Lifestyle4 out of 5', 'E...
# 2  ['Environment3 out of 5', 'Safety4 out of 5', ...
# 3  ['Environment5 out of 5', 'Lifestyle4 out of 5...
# 4  ['Environment4 out of 5', 'Safety4 out of 5', ...

# %%
# Create the folder if it doesn't exist
os.makedirs("../data/merged", exist_ok=True)

df.to_csv("../data/merged/gurgaon_properties.csv", index=False)

print("Merged dataset saved successfully!")
# Out:
# Merged dataset saved successfully!
