# %%
import os
import sys

PROJECT_ROOT = os.path.abspath("..")
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

print(PROJECT_ROOT)
# Out:
# d:\Property Intelligence Platform

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)

# %%
from src.data.ingestion import load_data

df = load_data("../data/feature_engineered/gurgaon_properties_cleaned_v2.csv")
# Out:
# Dataset loaded successfully.
# Rows: 3803
# Columns: 23

# %%
df.duplicated().sum()
# Out:
# np.int64(126)

# %%
df.drop_duplicates(inplace=True)

# %%
df.head()
# Out:
#   property_type                                  society      sector  price  \
# 0         house  sare crescent parc royal greens phase 1   sector 92   0.85
# 1          flat                  sare green parc phase 3   sector 92   1.08
# 2         house                 unitech uniworld resorts   sector 33   8.00
# 3          flat                       ireo the corridors  sector 67a   1.60
# 4         house                            rwa sector 46   sector 46   4.50
#
#    price_per_sqft    area                                       areaWithType  \
# 0          4877.0  1743.0                 Built Up area: 1743 (161.93 sq.m.)
# 1          5150.0  2097.0             Super Built up area 2090(194.17 sq.m.)
# 2         11428.0  7000.0                       Plot area 7000(650.32 sq.m.)
# 3          9264.0  1727.0  Super Built up area 1727(160.44 sq.m.)Carpet a...
# 4         24390.0  1845.0  Plot area 204(170.57 sq.m.)Built Up area: 206 ...
#
# ...

# %%
df.shape
# Out:
# (3677, 23)

# %%
df.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
#        'areaWithType', 'bedRoom', 'bathroom', 'balcony', 'floorNum', 'facing',
#        'agePossession', 'super_built_up_area', 'built_up_area', 'carpet_area',
#        'study room', 'servant room', 'store room', 'pooja room', 'others',
#        'furnishing_type', 'luxury_score'],
#       dtype='object')

# %%
# outliers on the basis of price column
sns.histplot(df['price'])
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.boxplot(x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df['price'] < lower_bound) | (df['price'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers.shape[0]
outliers_price_stats = outliers['price'].describe()

num_outliers, outliers_price_stats
# Out:
# (425,
#  count    425.000000
#  mean       9.235624
#  std        4.065259
#  min        5.460000
#  25%        6.460000
#  50%        8.000000
#  75%       10.750000
#  max       31.500000
#  Name: price, dtype: float64)

# %%
outliers
# Out:
#      property_type                              society       sector  price  \
# 2            house             unitech uniworld resorts    sector 33   8.00
# 6            house                     suncity township    sector 54  25.00
# 8            house                          independent    sector 46   5.65
# 18           house                          independent    sector 55   5.60
# 40           house                          independent    sector 82   7.00
# ...            ...                                  ...          ...    ...
# 3757         house  international city by sobha phase 2   sector 109  10.00
# 3777         house                          independent    sector 55   7.49
# 3789          flat               krrish provence estate  gwal pahari   7.50
# 3797         house                          independent    sector 56  12.39
# 3802          flat                       dlf the arbour    sector 63   7.52
#
#       price_per_sqft     area  \
# ...

# %%
outliers.to_excel(
    "../reports/outliers/price_outliers.xlsx",
    index=False
)

# %% [markdown]
# # on the basis of price col we can say that there are some genuine outliers but there are some data erros as well

# %% [markdown]
# ### Price_per_sqft

# %%
sns.histplot(df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft', ylabel='Count'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price_per_sqft'].quantile(0.25)
Q3 = df['price_per_sqft'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers_sqft = df[(df['price_per_sqft'] < lower_bound) | (df['price_per_sqft'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers_sqft.shape[0]
outliers_sqft_stats = outliers_sqft['price_per_sqft'].describe()

num_outliers, outliers_sqft_stats
# Out:
# (354,
#  count       354.000000
#  mean      52592.612994
#  std       61150.458507
#  min       24489.000000
#  25%       28208.250000
#  50%       33368.500000
#  75%       41982.250000
#  max      600000.000000
#  Name: price_per_sqft, dtype: float64)

# %%
outliers_sqft.to_excel(
    "../reports/outliers/price_per_sqft_outliers.xlsx",
    index=False
)

# %%
outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9276\205471443.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)

# %%
outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9276\3686006548.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])

# %%
outliers_sqft['price_per_sqft'].describe()
# Out:
# count      354.000000
# mean     29357.906780
# std      12403.077309
# min       2723.000000
# 25%      25562.000000
# 50%      29870.500000
# 75%      35549.500000
# max      82540.000000
# Name: price_per_sqft, dtype: float64

# %%
df.update(outliers_sqft)

# %%
sns.histplot(df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft', ylabel='Count'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
df[df['price_per_sqft']>50000]
# Out:
#      property_type                       society           sector  price  \
# 56           house                unitech escape        sector 50  10.80
# 139          house                dlf city plots        sector 26  26.00
# 808          house                   independent        sector 26  26.00
# 998          house            cloudnine cottages  sohna road road   5.50
# 1176         house                   independent        sector 26  14.75
# 1377         house                   independent        sector 25  16.00
# 1842          flat                unitech vistas        sector 70   9.00
# 2600         house            emaar mgf marbella        sector 66  18.00
# 2915         house  project housing board colony        sector 31   8.00
# 2955         house                           nul        sector 28  12.50
# 3109         house                  malibu towne        sector 47   8.50
# 3254         house        emaar the palm springs        sector 54  24.00
# ...

# %%
df = df[df['price_per_sqft'] <= 50000]

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %% [markdown]
# ### Area

# %%
sns.histplot(df['area'])
# Out:
# <Axes: xlabel='area', ylabel='Count'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count      3647.000000
# mean       2947.723608
# std       23208.194102
# min         145.000000
# 25%        1262.000000
# 50%        1750.000000
# 75%        2350.000000
# max      875000.000000
# Name: area, dtype: float64

# %%
df = df[df['area'] <100000]

# %%
sns.histplot(df['area'])
# Out:
# <Axes: xlabel='area', ylabel='Count'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
area_greater_than_10000 = df[df['area'] > 10000].sort_values('area',ascending=False)
area_greater_than_10000
# Out:
#      property_type                    society           sector  price  \
# 3679         house                independent        sector 26  18.40
# 1640         house  ganpati heights apartment        sector 13   1.25
# 2499          flat                 rof ananda        sector 95   0.38
# 324           flat                 rof ananda        sector 95   0.38
# 2125         house      dlf city plot phase 4        sector 28  13.00
# 333           flat              pyramid elite        sector 86   0.46
# 1974          flat                 rof ananda        sector 95   0.33
# 762           flat      signature the serenas       sohna road   0.28
# 3511         house                independent        sector 25   7.30
# 2346          flat            ramsons kshitij        sector 95   0.24
# 2735          flat                 rof ananda        sector 95   0.21
# 2017         house                independent        sector 57   6.25
# ...

# %%
df.shape
# Out:
# (3642, 23)

# %%
area_greater_than_10000.to_excel(
    "../reports/outliers/area_greater_than_10000.xlsx",
    index=False
)

# %%
area_greater_than_10000['area_per_room'] = area_greater_than_10000['area'] / (area_greater_than_10000['bedRoom'] + area_greater_than_10000['bathroom'])
area_greater_than_10000['area_per_room'].sort_values(ascending=False)
# Out:
# 762     24561.500000
# 2735    17213.000000
# 324     16379.250000
# 333     14557.000000
# 1974    13750.000000
# 2499    13103.400000
# 2346    11320.750000
# 3679     7069.857143
# 1640     5173.812500
# 2125     3263.050000
# 3511     2599.722222
# 3359     2579.833333
# 676      2248.666667
# 2738     2107.500000
# 43       2014.333333
# 1413     1799.833333
# 2775     1375.000000
# 2343     1350.000000
# 2017     1249.888889
# 1164      868.153846
# Name: area_per_room, dtype: float64

# %%
area_greater_than_10000
# Out:
#      property_type                    society           sector  price  \
# 3679         house                independent        sector 26  18.40
# 1640         house  ganpati heights apartment        sector 13   1.25
# 2499          flat                 rof ananda        sector 95   0.38
# 324           flat                 rof ananda        sector 95   0.38
# 2125         house      dlf city plot phase 4        sector 28  13.00
# 333           flat              pyramid elite        sector 86   0.46
# 1974          flat                 rof ananda        sector 95   0.33
# 762           flat      signature the serenas       sohna road   0.28
# 3511         house                independent        sector 25   7.30
# 2346          flat            ramsons kshitij        sector 95   0.24
# 2735          flat                 rof ananda        sector 95   0.21
# 2017         house                independent        sector 57   6.25
# ...

# %%
index=area_greater_than_10000[(area_greater_than_10000['area_per_room'] > 4000) & (area_greater_than_10000['price'] < 1.0)].index

# %%
df.drop(index, inplace=True)

# %%
df.shape
# Out:
# (3635, 23)

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)
# Out:
#      property_type                    society           sector  price  \
# 3679         house                independent        sector 26  18.40
# 1640         house  ganpati heights apartment        sector 13   1.25
# 2125         house      dlf city plot phase 4        sector 28  13.00
# 3511         house                independent        sector 25   7.30
# 2017         house                independent        sector 57   6.25
# 2343         house                independent        sector 43   5.50
# 43            flat                 godrej air        sector 85   2.50
# 3359         house       unitech aspen greens        sector 50   6.95
# 676          house                independent         sector 4   0.85
# 2738          flat                godrej icon       sector 88a   1.75
# 1164         house                independent        sector 43  27.50
# 2775          flat             m3m golfestate        sector 65  13.20
# ...

# %%
large_area = df[df['area'] > 10000].copy()

# %%
large_area
# Out:
#      property_type                    society           sector  price  \
# 43            flat                 godrej air        sector 85   2.50
# 676          house                independent         sector 4   0.85
# 1164         house                independent        sector 43  27.50
# 1413         house                independent  sohna road road   5.50
# 1640         house  ganpati heights apartment        sector 13   1.25
# 2017         house                independent        sector 57   6.25
# 2125         house      dlf city plot phase 4        sector 28  13.00
# 2343         house                independent        sector 43   5.50
# 2738          flat                godrej icon       sector 88a   1.75
# 2775          flat             m3m golfestate        sector 65  13.20
# 3359         house       unitech aspen greens        sector 50   6.95
# 3511         house                independent        sector 25   7.30
# ...

# %%
large_area['max_area'] = large_area[
    ['super_built_up_area', 'built_up_area', 'carpet_area']
].max(axis=1)

# %%
large_area
# Out:
#      property_type                    society           sector  price  \
# 43            flat                 godrej air        sector 85   2.50
# 676          house                independent         sector 4   0.85
# 1164         house                independent        sector 43  27.50
# 1413         house                independent  sohna road road   5.50
# 1640         house  ganpati heights apartment        sector 13   1.25
# 2017         house                independent        sector 57   6.25
# 2125         house      dlf city plot phase 4        sector 28  13.00
# 2343         house                independent        sector 43   5.50
# 2738          flat                godrej icon       sector 88a   1.75
# 2775          flat             m3m golfestate        sector 65  13.20
# 3359         house       unitech aspen greens        sector 50   6.95
# 3511         house                independent        sector 25   7.30
# ...

# %%
large_area['total_rooms'] = large_area['bedRoom'] + large_area['bathroom']

# %%
large_area['area_per_room'] = large_area['max_area'] / large_area['total_rooms']

# %%
large_area.sort_values('area_per_room', ascending=False)[
    ['property_type', 'sector', 'price',
     'super_built_up_area', 'built_up_area', 'carpet_area',
     'max_area', 'bedRoom', 'bathroom', 'area_per_room']
]
# Out:
#      property_type           sector  price  super_built_up_area  \
# 676          house         sector 4   0.85                  NaN
# 43            flat        sector 85   2.50                  NaN
# 2775          flat        sector 65  13.20                  NaN
# 1164         house        sector 43  27.50                  NaN
# 3679         house        sector 26  18.40                  NaN
# 1413         house  sohna road road   5.50                  NaN
# 2125         house        sector 28  13.00                  NaN
# 3359         house        sector 50   6.95                  NaN
# 3511         house        sector 25   7.30                  NaN
# 2738          flat       sector 88a   1.75                  NaN
# 2343         house        sector 43   5.50                  NaN
# 2017         house        sector 57   6.25                  NaN
# 1640         house        sector 13   1.25                  NaN
#
# ...

# %%
df.loc[large_area.index, 'area'] = large_area['max_area']

# %%
idx_to_drop=large_area[large_area['area_per_room'] < 150].index
df.drop(idx_to_drop, inplace=True)

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9276\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count     3633.000000
# mean      1958.564027
# std       1260.114203
# min        145.000000
# 25%       1261.000000
# 50%       1749.000000
# 75%       2332.000000
# max      18122.000000
# Name: area, dtype: float64

# %% [markdown]
# ### Bedroom

# %%
sns.distplot(df['bedRoom'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9276\1691983684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])
# <Axes: xlabel='bedRoom', ylabel='Density'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3633.000000
# mean        3.330856
# std         1.824810
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        21.000000
# Name: bedRoom, dtype: float64

# %%
df[df['bedRoom'] > 10].sort_values('bedRoom',ascending=False)
# Out:
#      property_type                      society      sector  price  \
# 354          house                  independent   sector 54   5.00
# 1619         house                  independent   sector 43   4.50
# 2779         house                  independent  sector 17a   3.87
# 1071         house                  independent  sector 17a   3.93
# 2332         house                  independent   sector 54   5.50
# 2880         house                private house   sector 55   7.05
# 1292         house       luxury dlf city floors   sector 26  20.00
# 1660         house                  independent   sector 43  13.50
# 3220         house                  independent   sector 40  12.00
# 3476         house                  independent   sector 55   9.19
# 3797         house                  independent   sector 56  12.39
# 3638         house               dlf city plots   sector 26  20.00
# 3767         house                  independent   sector 11   4.50
# ...

# %%
df = df[df['bedRoom'] <= 10]

# %%
df.shape
# Out:
# (3588, 23)

# %%
sns.distplot(df['bedRoom'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9276\1691983684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])
# <Axes: xlabel='bedRoom', ylabel='Density'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3588.000000
# mean        3.200948
# std         1.386754
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        10.000000
# Name: bedRoom, dtype: float64

# %% [markdown]
# ### Bathroom

# %%
sns.distplot(df['bathroom'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9276\2904465235.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bathroom'])
# <Axes: xlabel='bathroom', ylabel='Density'>

# %%
sns.boxplot(x=df['bathroom'])
# Out:
# <Axes: xlabel='bathroom'>

# %%
df[df['bathroom'] > 10].sort_values('bathroom',ascending=False)
# Out:
#      property_type               society     sector  price  price_per_sqft  \
# 1880         house  adani brahma samsara  sector 60  18.02         28200.0
# 1701         house           independent  sector 24  11.00         28902.0
# 1948         house           independent  sector 39   7.00         10000.0
#
#         area                                       areaWithType  bedRoom  \
# 1880  6390.0                 Built Up area: 6390 (593.65 sq.m.)        9
# 1701  3806.0  Plot area 3806.45(353.63 sq.m.)Built Up area: ...        8
# 1948  7000.0  Plot area 350(32.52 sq.m.)Built Up area: 7000 ...       10
#
#       bathroom balcony  floorNum      facing   agePossession  \
# 1880        12      3+       3.0  North-East  Relatively New
# 1701        11      3+       3.0        East    Old Property
# 1948        11      3+       4.0  South-East  Relatively New
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# ...

# %%
df.head()
# Out:
#   property_type                                  society      sector  price  \
# 0         house  sare crescent parc royal greens phase 1   sector 92   0.85
# 1          flat                  sare green parc phase 3   sector 92   1.08
# 2         house                 unitech uniworld resorts   sector 33   8.00
# 3          flat                       ireo the corridors  sector 67a   1.60
# 4         house                            rwa sector 46   sector 46   4.50
#
#    price_per_sqft    area                                       areaWithType  \
# 0          4877.0  1743.0                 Built Up area: 1743 (161.93 sq.m.)
# 1          5150.0  2097.0             Super Built up area 2090(194.17 sq.m.)
# 2         11428.0  7000.0                       Plot area 7000(650.32 sq.m.)
# 3          9264.0  1727.0  Super Built up area 1727(160.44 sq.m.)Carpet a...
# 4         24390.0  1845.0  Plot area 204(170.57 sq.m.)Built Up area: 206 ...
#
# ...

# %% [markdown]
# ### super built up area

# %%
sns.distplot(df['super_built_up_area'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9276\939662859.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['super_built_up_area'])
# <Axes: xlabel='super_built_up_area', ylabel='Density'>

# %%
sns.boxplot(x=df['super_built_up_area'])
# Out:
# <Axes: xlabel='super_built_up_area'>

# %%
df['super_built_up_area'].describe()
# Out:
# count     1875.000000
# mean      1925.237627
# std        764.172177
# min         89.000000
# 25%       1479.500000
# 50%       1828.000000
# 75%       2215.000000
# max      10000.000000
# Name: super_built_up_area, dtype: float64

# %%
df[df['super_built_up_area'] > 6000]
# Out:
#      property_type                      society       sector  price  \
# 23            flat  bestech park view grand spa    sector 81    4.7
# 3789          flat       krrish provence estate  gwal pahari    7.5
#
#       price_per_sqft     area                             areaWithType  \
# 23            6786.0   6926.0   Super Built up area 6926(643.45 sq.m.)
# 3789          7500.0  10000.0  Super Built up area 10000(929.03 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 23          4         4      3+      19.0       North  Relatively New
# 3789        5         6      3+      23.0  North-East  Relatively New
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# 23                 6926.0            NaN          NaN           0
# 3789              10000.0            NaN          NaN           0
#
#       servant room  store room  pooja room  others  furnishing_type  \
# ...

# %% [markdown]
# ### built up area

# %%
sns.distplot(df['built_up_area'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9276\3494228458.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['built_up_area'])
# <Axes: xlabel='built_up_area', ylabel='Density'>

# %%
sns.boxplot(x=df['built_up_area'])
# Out:
# <Axes: xlabel='built_up_area'>

# %%
df[df['built_up_area'] > 10000]
# Out:
#      property_type      society     sector  price  price_per_sqft     area  \
# 676          house  independent   sector 4   0.85           630.0  13500.0
# 1164         house  independent  sector 43  27.50         24366.0  11286.0
#
#                        areaWithType  bedRoom  bathroom balcony  floorNum  \
# 676   Plot area 1500(1254.19 sq.m.)        3         3       1       1.0
# 1164   Plot area 1254(1048.5 sq.m.)        6         7      3+       3.0
#
#           facing   agePossession  super_built_up_area  built_up_area  \
# 676        North  Relatively New                  NaN        13500.0
# 1164  North-East  Relatively New                  NaN        11286.0
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 676           NaN           0             0           0           0       1
# 1164          NaN           1             1           0           1       1
#
#       furnishing_type  luxury_score
# 676                 0             0
# ...

# %% [markdown]
# ### carpet area

# %%
sns.distplot(df['carpet_area'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9276\3905767603.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['carpet_area'])
# <Axes: xlabel='carpet_area', ylabel='Density'>

# %%
sns.boxplot(x=df['carpet_area'])
# Out:
# <Axes: xlabel='carpet_area'>

# %%
df[df['carpet_area'] > 10000]
# Out:
#      property_type         society     sector  price  price_per_sqft     area  \
# 43            flat      godrej air  sector 85    2.5          1379.0  18122.0
# 2775          flat  m3m golfestate  sector 65   13.2         12000.0  11000.0
# 3679         house     independent  sector 26   18.4          1859.0  11000.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 43                   Carpet area: 18122 (1683.59 sq.m.)        4         5
# 2775                 Carpet area: 11000 (1021.93 sq.m.)        4         4
# 3679  Plot area 502(419.74 sq.m.)Carpet area: 11000 ...        6         8
#
#      balcony  floorNum      facing       agePossession  super_built_up_area  \
# 43        3+      16.0  North-East  Under Construction                  NaN
# 2775       3      13.0       North      Moderately Old                  NaN
# 3679      3+       4.0       South      Relatively New                  NaN
#
# ...

# %%
df.head()
# Out:
#   property_type                                  society      sector  price  \
# 0         house  sare crescent parc royal greens phase 1   sector 92   0.85
# 1          flat                  sare green parc phase 3   sector 92   1.08
# 2         house                 unitech uniworld resorts   sector 33   8.00
# 3          flat                       ireo the corridors  sector 67a   1.60
# 4         house                            rwa sector 46   sector 46   4.50
#
#    price_per_sqft    area                                       areaWithType  \
# 0          4877.0  1743.0                 Built Up area: 1743 (161.93 sq.m.)
# 1          5150.0  2097.0             Super Built up area 2090(194.17 sq.m.)
# 2         11428.0  7000.0                       Plot area 7000(650.32 sq.m.)
# 3          9264.0  1727.0  Super Built up area 1727(160.44 sq.m.)Carpet a...
# 4         24390.0  1845.0  Plot area 204(170.57 sq.m.)Built Up area: 206 ...
#
# ...

# %% [markdown]
# ### Luxury Score

# %%
sns.distplot(df['luxury_score'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9276\3385064764.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['luxury_score'])
# <Axes: xlabel='luxury_score', ylabel='Density'>

# %%
sns.boxplot(df['luxury_score'])
# Out:
# <Axes: ylabel='luxury_score'>

# %%
df.shape
# Out:
# (3588, 23)

# %%
df['price_per_sqft'] = round((df['price']*10000000)/df['area'])

# %%
df.head()
# Out:
#   property_type                                  society      sector  price  \
# 0         house  sare crescent parc royal greens phase 1   sector 92   0.85
# 1          flat                  sare green parc phase 3   sector 92   1.08
# 2         house                 unitech uniworld resorts   sector 33   8.00
# 3          flat                       ireo the corridors  sector 67a   1.60
# 4         house                            rwa sector 46   sector 46   4.50
#
#    price_per_sqft    area                                       areaWithType  \
# 0          4877.0  1743.0                 Built Up area: 1743 (161.93 sq.m.)
# 1          5150.0  2097.0             Super Built up area 2090(194.17 sq.m.)
# 2         11429.0  7000.0                       Plot area 7000(650.32 sq.m.)
# 3          9265.0  1727.0  Super Built up area 1727(160.44 sq.m.)Carpet a...
# 4         24390.0  1845.0  Plot area 204(170.57 sq.m.)Built Up area: 206 ...
#
# ...

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9276\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(df['price_per_sqft'])
# Out:
# <Axes: ylabel='price_per_sqft'>

# %%
df[df['price_per_sqft'] > 42000]
# Out:
#      property_type                       society      sector  price  \
# 45           house                   independent   sector 55    5.0
# 51           house                dlf city plots   sector 26   19.0
# 555          house                   independent   sector 28   12.0
# 666          house                   independent   sector 26   20.0
# 863          house                   independent   sector 25   13.0
# 1197         house                   independent  sector 105    9.9
# 1211         house                   independent   sector 43    9.5
# 1644         house  sushant lok 1 builder floors   sector 43   13.0
# 3489         house                   independent   sector 26   19.0
#
#       price_per_sqft    area  \
# 45           44444.0  1125.0
# 51           42054.0  4518.0
# 555          42194.0  2844.0
# 666          44444.0  4500.0
# 863          45710.0  2844.0
# 1197         49500.0  2000.0
# 1211         42222.0  2250.0
# 1644         48148.0  2700.0
# ...

# %%
x = df[df['price_per_sqft'] <= 20000]
(x['area']/x['bedRoom']).quantile(0.05)
# Out:
# np.float64(252.5)

# %%
df["area_room_ratio"] = df["area"] / df["bedRoom"]

# %%
filtered_df = df[(df['area'] / df['bedRoom']) < 250]

filtered_df.to_excel("../reports/outliers/low_area_per_bedroom.xlsx", index=False)

# %%
filtered_df['bedRoom'].value_counts()
# Out:
# bedRoom
# 2     47
# 3     33
# 5     28
# 6     17
# 4     17
# 9     15
# 8     12
# 7      8
# 10     7
# Name: count, dtype: int64

# %%
sns.lmplot(x='area', y='bedRoom', data=df)

# %%
df[df['area_room_ratio']<100]
# Out:
#      property_type                          society  \
# 235          house                      independent
# 345          house                        jacobpura
# 613          house                      independent
# 937          house                        rk excelo
# 1011         house                   not applicable
# 1257         house                         ss omnia
# 1390         house                    sector 38 rwa
# 1407         house  ashok vihar phase iii extension
# 1641         house            rajendra park gurgaon
# 2192         house                    rattan garden
# 2402         house                      independent
# 2444         house                      independent
# 2479         house                      independent
# 2510         house                            ansal
# 2580         house                      independent
# 3059         house                      independent
# 3174         house                      independent
# ...

# %%
df=df[df['area_room_ratio']>100]

# %%
outlier=df[(df['area_room_ratio']<250) & (df['bedRoom']>3)]

# %%
outlier
# Out:
#      property_type         society            sector  price  price_per_sqft  \
# 31           house     independent         sector 24   4.50         33333.0
# 45           house     independent         sector 55   5.00         44444.0
# 173          house     independent         sector 12   2.50         13889.0
# 195          house     independent         sector 24   3.50         32407.0
# 251          house  uppal southend         sector 49   3.75         25562.0
# ...            ...             ...               ...    ...             ...
# 3459         house     independent         sector 47   4.30         29312.0
# 3545         house     independent         sector 12   0.90         13333.0
# 3552         house     independent  sector 3 phase 2   0.85          9444.0
# 3583         house     independent         sector 13   1.50         11538.0
# 3641         house     independent         sector 17   0.32          5664.0
#
# ...

# %%
outlier['bedRoom']= round(outlier['bedRoom']/outlier['floorNum'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9276\994019679.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outlier['bedRoom']= round(outlier['bedRoom']/outlier['floorNum'])

# %%
df.update(outlier)

# %%
df['area_room_ratio'] = df["area"] / df["bedRoom"]

# %%
df[(df['area_room_ratio']<250) & (df['bedRoom']>4)]
# Out:
#      property_type               society            sector  price  \
# 173          house           independent         sector 12   2.50
# 270          house           independent         sector 12   0.65
# 490          house           independent          sector 7   1.16
# 692          house           independent        sector 105   1.10
# 1429         house           independent           manesar   1.10
# 1553         house  bhim nagar, sector 6          sector 6   0.85
# 1639         house           independent         sector 11   3.50
# 2197         house           independent          sector 2   0.98
# 2498         house              shivpuri          sector 7   2.80
# 2544         house           independent  sector 3 phase 2   1.10
# 3124         house           independent           manesar   0.80
# 3552         house           independent  sector 3 phase 2   0.85
# 3641         house           independent         sector 17   0.32
#
#       price_per_sqft    area  \
# ...

# %%
df=df[~((df['area_room_ratio']<250) & (df['bedRoom']>4))]

# %%
sns.lmplot(data=df,x='area',y='bedRoom')

# %%
df.shape
# Out:
# (3555, 24)

# %%
# Create the folder if it doesn't exist
os.makedirs("../data/feature_engineered", exist_ok=True)

df.to_csv("../data/feature_engineered/gurgaon_properties_outlier_treated.csv", index=False)

print("Outlier-treated dataset saved successfully!")
# Out:
# Outlier-treated dataset saved successfully!
